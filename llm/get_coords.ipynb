# %%
import pandas as pd
import re
import emoji
import json
from tqdm import tqdm

# %%
df = pd.read_csv("../datasets/jptweets.csv")

# %%
df = df.drop_duplicates(subset='text', keep='first')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 978 entries, 0 to 1082
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          978 non-null    object
#  1   text        977 non-null    object
#  2   time stamp  978 non-null    object
# dtypes: object(3)
# memory usage: 30.6+ KB

# %% [markdown]
# ### Pre-processing

# %%
def clean_tweet(tweet):
    if not isinstance(tweet, str):
        tweet = ""
    tweet = re.sub(r"http\S+|www\S+|https\S+", " ", tweet, flags=re.MULTILINE)
    tweet = re.sub(r"@|#|:|_", " ", tweet)
    tweet = re.sub(r",", ", ", tweet)
    tweet = re.sub(r"!", "! ", tweet)
    tweet = re.sub(r"\?", "? ", tweet)
    tweet = re.sub(r";", "; ", tweet)
    tweet = re.sub(r"[^\w\s.,!?;]", " ", tweet)
    tweet = emoji.replace_emoji(tweet, " ")  
    tweet = re.sub(r"(?<!\d)\.|(?<=\d)\.(?!\d)|(?<!\d)\.(?!\d)", ". ", tweet)
    tweet = re.sub(r"(?<=\d)\. (?=\d)", ".", tweet)
    tweet = re.sub(r"\s+", " ", tweet).strip()
    return tweet

def is_ascii(text):
    return all(ord(char) < 128 for char in text)


df['text'] = df['text'].apply(clean_tweet)
df = df[df['text'].apply(is_ascii)]
df = df[df['text'].str.strip() != '']
df = df.reset_index(drop=True)

df
# Out:
#                    id                                               text  \
# 0            @EN_NERV  Major Tsunami Warning 1 1, 4 22pm The Tsunami ...
# 1      @diar_esthetic  According to mathematical and tectonophysical ...
# 2    @LiveStormChaser  Earlier video showing smaller wave caused by t...
# 3            @EN_NERV  Tsunami Advisory 8 8, 4 44pm A Tsunami Advisor...
# 4        @volcaholic1  UNCONFIRMED video of considerable damage in No...
# ..                ...                                                ...
# 750      @SallySueIam                              Replying to mattgaetz
# 751     @NathanNoonan                    Replying to Terumi4416 and fema
# 752        @mntomorii                        Replying to ceriseaustralis
# 753     @mrsverypicky  Japan s NotoEarthquake thousands of survivors ...
# 754       @Janis_cats              Replying to Janis cats and In2ThinAir
#
#      time stamp
# 0    2024-01-01
# 1    2024-10-07
# 2    2024-01-01
# 3    2024-08-08
# 4    2024-01-01
# ..          ...
# 750  2024-10-06
# 751  2024-10-07
# 752  2024-10-02
# 753  2024-02-14
# 754  2024-10-03
#
# [755 rows x 3 columns]

# %%
def find_non_ascii_chars(tweet):
    return set(char for char in tweet if ord(char) >= 128)

non_ascii_chars = set()
for tweet in df['text']:
    non_ascii_chars.update(find_non_ascii_chars(tweet))

print("Unique non-ASCII characters found in the tweets:")
print(non_ascii_chars)
# Out:
# Unique non-ASCII characters found in the tweets:
# set()

# %%
jp = pd.read_csv('../datasets/jp.csv')
city = pd.read_csv('../datasets/city.csv')
countries = pd.read_csv('../datasets/countries.csv')
added_locs = pd.read_csv('../datasets/added_locs.csv')
# Out:
# C:\Users\deepp\AppData\Local\Temp\ipykernel_33860\310253923.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   jp = pd.read_csv('../datasets/jp.csv')

# %%
jp = jp[jp['feature class'].isin(['A', 'P'])]

# %%
jp = jp[jp['population']>0]

# %%
jp
# Out:
#        Unnamed: 0  geonameid             name        asciiname  \
# 2         4766202    1847945      Tatsuno-shi      Tatsuno-shi
# 4         4766204    1847947           Shingū           Shingu
# 19        4766219    1847963           Atsugi           Atsugi
# 22        4766222    1847966           Akashi           Akashi
# 24        4766224    1847968            Zushi            Zushi
# ...           ...        ...              ...              ...
# 89018     4855218   11497708       Masaki-chō       Masaki-cho
# 89021     4855221   11523579  Yonedacho Sendo  Yonedacho Sendo
# 89022     4855222   11524139           Hokuto           Hokuto
# 90711     4856911   11668516         Aioi Shi         Aioi Shi
# 90712     4856912   11668552       Yashio-shi       Yashio-shi
#
#                                           alternatenames  latitude  longitude  \
# 2      Tatsuno;Tatsuno-cho;Tatsuno-chō;Tatsuno-machi;...  34.88804  134.51910
# 4      Schingu;Shingu;Shingui;Shingū;Sing;Singu;Singu...  33.73333  135.98333
# 19     Acugi;Atsugi;Atsugicho;Atsugichō;Atsuki;Atugi;...  35.44272  139.36931
# 22     Akashi;Akasi;Akasi-chhi;Akasi-chhī;Akasis;Akas...  34.65524  135.00687
# 24                           Zushi;dou zi;zushi;ずし;ズシ;逗子  35.29483  139.57812
# ...                                                  ...       ...        ...
# 89018                                                NaN  33.79242  132.72446
# 89021                                                NaN  34.77560  134.82551
# 89022                           bei du;bei du shi;北杜;北杜市  35.83458  138.39606
# 90711                                xiang sheng shi;相生市  34.82719  134.46699
# 90712                                    ba chao shi;八潮市  35.80918  139.84669
#
#       feature class feature code country code  cc2  admin1 code  admin2 code  \
# 2                 A         ADM2           JP  NaN         13.0    1847945.0
# 4                 P        PPLA2           JP  NaN         43.0    1852105.0
# 19                P        PPLA2           JP  NaN         19.0    1864928.0
# 22                P        PPLA2           JP  NaN         13.0    1865470.0
# 24                P        PPLA2           JP  NaN         19.0    7470888.0
# ...             ...          ...          ...  ...          ...          ...
# 89018             A         ADM3           JP  NaN          5.0    1861141.0
# 89021             P         PPLX           JP  NaN         13.0    1860702.0
# 89022             P        PPLA2           JP  NaN         46.0    7415915.0
# 90711             A         ADM2           JP  NaN         13.0   11668516.0
# 90712             A         ADM2           JP  NaN         34.0   11668552.0
#
#        admin3 code  admin4 code  population  elevation  dem    timezone  \
# 2              NaN          NaN       79870        NaN  250  Asia/Tokyo
# 4              NaN          NaN       31619        NaN    7  Asia/Tokyo
# 19             NaN          NaN      229199        NaN   26  Asia/Tokyo
# 22             NaN          NaN      297279        NaN   27  Asia/Tokyo
# 24             NaN          NaN       60055        NaN    9  Asia/Tokyo
# ...            ...          ...         ...        ...  ...         ...
# 89018      38401.0          NaN       31168        NaN   13  Asia/Tokyo
# 89021          NaN          NaN        6000        NaN   54  Asia/Tokyo
# 89022          NaN          NaN       45000        NaN  731  Asia/Tokyo
# 90711          NaN          NaN       30931        NaN  100  Asia/Tokyo
# 90712          NaN          NaN       84904        NaN    5  Asia/Tokyo
#
#       modification date
# 2            2017-07-21
# 4            2017-07-22
# 19           2017-07-22
# 22           2017-07-28
# 24           2017-07-22
# ...                 ...
# 89018        2017-04-07
# 89021        2017-04-14
# 89022        2017-07-21
# 90711        2017-08-07
# 90712        2017-08-07
#
# [2519 rows x 20 columns]

# %%
city
# Out:
#      Unnamed: 0  geonameid                             name  \
# 0         37927    1149361  Islamic Republic of Afghanistan
# 1        131289    2240444                  Luanda Province
# 2        141795    3351879               Republic of Angola
# 3        202632    3435907        Provincia de Buenos Aires
# 4        236675    3865483               Argentine Republic
# ..          ...        ...                              ...
# 366    10987267    1085593                     Eastern Cape
# 367    10987268    1085594                          Gauteng
# 368    10987271    1085597                          Limpopo
# 369    11005424     895949               Republic of Zambia
# 370    11031514     878675             Republic of Zimbabwe
#
#                            asciiname  \
# 0    Islamic Republic of Afghanistan
# 1                    Luanda Province
# 2                 Republic of Angola
# 3          Provincia de Buenos Aires
# 4                 Argentine Republic
# ..                               ...
# 366                     Eastern Cape
# 367                          Gauteng
# 368                          Limpopo
# 369               Republic of Zambia
# 370             Republic of Zimbabwe
#
#                                         alternatenames  latitude  longitude  \
# 0    'Afikanisitani;'Apekanikana;A Phu Han (Afghani...  33.00000   66.00000
# 1    Distrito de Luanda;Loanda;Luanda;Luanda Provin...  -8.91667   13.33924
# 2    'Enikola;Africa Ocidental Portuguesa;An'nkola;... -12.50000   18.50000
# 3            BA;Buenos Aires;Provincia de Buenos Aires -36.00000  -60.00000
# 4    'Asenitina;A Can GJinh (Argentina);Ac-hen-ti-n... -34.00000  -64.00000
# ..                                                 ...       ...        ...
# 366  Austrumkapa;Austrumkāpa;Cabo Oriental;Cap Orie... -32.00000   26.00000
# 367  Chrysotopia;Gauteng;Gauteng Gobol;Gauteng-sen;... -26.08333   28.25000
# 368  IPhondo yaLimpopo;Kgaolo ya Limpopo;Limpopas;L... -24.00000   29.50000
# 369  An tSaimbia;Dam-bi-a;Dam-bi-a (Zambia);Dăm-bi-... -14.33333   28.50000
# 370  An tSiombaib;An tSiombáib;Cimbabue;Colony of R... -19.00000   29.75000
#
#     feature class feature code country code  cc2 admin1 code admin2 code  \
# 0               A         PCLI           AF  NaN           0         NaN
# 1               A         ADM1           AO  NaN        20.0         NaN
# 2               A         PCLI           AO  NaN         0.0         NaN
# 3               A         ADM1           AR  NaN         1.0         NaN
# 4               A         PCLI           AR  NaN          00         NaN
# ..            ...          ...          ...  ...         ...         ...
# 366             A         ADM1           ZA  NaN         5.0         NaN
# 367             A         ADM1           ZA  NaN         6.0         NaN
# 368             A         ADM1           ZA  NaN         9.0         NaN
# 369             A         PCLI           ZM  NaN         0.0         NaN
# 370             A         PCLI           ZW  NaN         0.0         NaN
#
#      admin3 code  admin4 code  population  elevation   dem  \
# 0            NaN          NaN    29121286        NaN  2260
# 1            NaN          NaN     6542942        NaN   103
# 2            NaN          NaN    13068161        NaN  1355
# 3            NaN          NaN    13827203        NaN    54
# 4            NaN          NaN    41343201        NaN   189
# ..           ...          ...         ...        ...   ...
# 366          NaN          NaN     6490714        NaN  1125
# 367          NaN          NaN    10058121        NaN  1652
# 368          NaN          NaN     5494928        NaN  1373
# 369          NaN          NaN    13460305        NaN  1156
# 370          NaN          NaN    13061000        NaN  1285
#
#                            timezone modification date
# 0                        Asia/Kabul        2015-10-07
# 1                     Africa/Luanda        2016-05-04
# 2                     Africa/Luanda        2013-04-03
# 3    America/Argentina/Buenos_Aires        2014-06-11
# 4                               NaN        2016-02-01
# ..                              ...               ...
# 366             Africa/Johannesburg        2014-07-30
# 367             Africa/Johannesburg        2016-11-04
# 368             Africa/Johannesburg        2016-11-09
# 369                   Africa/Lusaka        2016-09-12
# 370                   Africa/Harare        2016-03-31
#
# [371 rows x 20 columns]

# %%
countries
# Out:
#      Unnamed: 0      Country Density(P/Km2) Abbreviation  \
# 0             0  Afghanistan             60           AF
# 1             2      Algeria             18           DZ
# 2             4       Angola             26           AO
# 3             6    Argentina             17           AR
# 4             8    Australia              3           AU
# ..          ...          ...            ...          ...
# 106         190    Venezuela             32           VE
# 107         191      Vietnam            314           VN
# 108         192        Yemen             56           YE
# 109         193       Zambia             25           ZM
# 110         194     Zimbabwe             38           ZW
#
#     Agricultural Land( %) Land Area(Km2) Armed Forces size  Birth Rate  \
# 0                  58.10%        652,230           323,000       32.49
# 1                  17.40%      2,381,741           317,000       24.28
# 2                  47.50%      1,246,700           117,000       40.73
# 3                  54.30%      2,780,400           105,000       17.02
# 4                  48.20%      7,741,220            58,000       12.60
# ..                    ...            ...               ...         ...
# 106                24.50%        912,050           343,000       17.88
# 107                39.30%        331,210           522,000       16.75
# 108                44.60%        527,968            40,000       30.45
# 109                32.10%        752,618            16,000       36.19
# 110                41.90%        390,757            51,000       30.68
#
#      Calling Code Capital/Major City  ... Out of pocket health expenditure  \
# 0            93.0              Kabul  ...                           78.40%
# 1           213.0            Algiers  ...                           28.10%
# 2           244.0             Luanda  ...                           33.40%
# 3            54.0       Buenos Aires  ...                           17.60%
# 4            61.0           Canberra  ...                           19.60%
# ..            ...                ...  ...                              ...
# 106          58.0            Caracas  ...                           45.80%
# 107          84.0              Hanoi  ...                           43.50%
# 108         967.0              Sanaa  ...                           81.00%
# 109         260.0             Lusaka  ...                           27.50%
# 110         263.0             Harare  ...                           25.80%
#
#     Physicians per thousand Population  \
# 0                      0.28   38041754
# 1                      1.72   43053054
# 2                      0.21   31825295
# 3                      3.96   44938712
# 4                      3.68   25766605
# ..                      ...        ...
# 106                    1.92   28515829
# 107                    0.82   96462106
# 108                    0.31   29161922
# 109                    1.19   17861030
# 110                    0.21   14645468
#
#     Population: Labor force participation (%)  Tax revenue (%) Total tax rate  \
# 0                                      48.90%            9.30%         71.40%
# 1                                      41.20%           37.20%         66.10%
# 2                                      77.50%            9.20%         49.10%
# 3                                      61.30%           10.10%        106.30%
# 4                                      65.50%           23.00%         47.40%
# ..                                        ...              ...            ...
# 106                                    59.70%              NaN         73.30%
# 107                                    77.40%           19.10%         37.60%
# 108                                    38.00%              NaN         26.60%
# 109                                    74.60%           16.20%         15.60%
# 110                                    83.10%           20.70%         31.60%
#
#     Unemployment rate Urban_population   Latitude   Longitude
# 0              11.12%        9,797,273  33.939110   67.709953
# 1              11.70%       31,510,100  28.033886    1.659626
# 2               6.89%       21,061,025 -11.202692   17.873887
# 3               9.79%       41,339,571 -38.416097  -63.616672
# 4               5.27%       21,844,756 -25.274398  133.775136
# ..                ...              ...        ...         ...
# 106             8.80%       25,162,368   6.423750  -66.589730
# 107             2.01%       35,332,140  14.058324  108.277199
# 108            12.91%       10,869,523  15.552727   48.516388
# 109            11.43%        7,871,713 -13.133897   27.849332
# 110             4.95%        4,717,305 -19.015438   29.154857
#
# [111 rows x 36 columns]

# %%
a = list(jp['asciiname']) + list(city['name']) + list(countries['Country']) + list(added_locs['location'])

city_list = list(
    set(re.sub(r'[^a-zA-Z]', ' ', str(element)).strip() for element in a if element is not None)
)

city_list.sort()

# %%
locations = pd.DataFrame(city_list, columns=['location'])

# %%
locations
# Out:
#           location
# 0         Abashiri
# 1     Abashiri shi
# 2            Abiko
# 3        Abiko shi
# 4        Abira Cho
# ...            ...
# 2958         Zushi
# 2959     Zushi Shi
# 2960  le de France
# 2961       saka fu
# 2962       stanbul
#
# [2963 rows x 1 columns]

# %%
locations.to_csv('../datasets/jpgpe1.csv', index=False)

# %%
len(city_list)
# Out:
# 2963

# %%
jsonl_data = []

for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing rows"):
    content = row["text"]
    hashtags = city_list

    entities = []
    
    for hashtag in hashtags:
        if isinstance(hashtag, str):
            lowercase_hashtag = hashtag.lower()
        else:
            lowercase_hashtag = str(hashtag).lower()
        
        pattern = r'\b' + re.escape(lowercase_hashtag) + r'\b'
        matches = re.finditer(pattern, content.lower())
        for match in matches:
            start_idx = match.start()
            end_idx = match.end()
            if [start_idx, end_idx, "GPE"] not in entities:
                entities.append([start_idx, end_idx, "GPE"])
    
    jsonl_data.append([f"{content} ", {"entities": entities}])

with open("../datasets/test/1xjp.jsonl", "w", encoding="utf-8") as jsonl_file:
    for entry in jsonl_data:
        json.dump(entry, jsonl_file)
        jsonl_file.write("\n")
# Out:
# Processing rows: 100%|██████████| 755/755 [01:11<00:00, 10.49it/s]

# %%
disaster_keywords = [
    "earthquake", "tremor", "aftershock", "seismic", "fault", "epicenter",
    "magnitude", "Richter scale", "shaking", "ground", "foreshock",
    "tectonic", "plate", "shockwave", "aftermath", "felt", "feel",
    "strong", "massive", "devastating", "violent", "powerful", "intense",
    "mild", "deep", "surface", "shallow", "damage", "collapse", "ruins", "wreckage",
    "destroyed", "cracks", "crumbling", "impact", "disaster", "displaced",
    "homeless", "injury", "injuries", "fatalities", "debris", "rubble", "casualties",
    "trapped", "died", "alert", "warning", "evacuation", "rescue",
    "search", "emergency", "relief", "assistance", "volunteers", "preparedness",
    "shelter", "efforts", "response team", "seismograph", "seismology",
    "intensity", "measurement", "USGS", "depth", "geological", "seismometer",
    "tsunami", "landslide", "fire", "eruption", "volcano", "flood", "pray", "thoughts",
    "fear", "panic", "trauma", "loss", "tragedy", "devastation", "solidarity", "support"
]

# %%
input_file = "../datasets/test/1xjp.jsonl"  
jsonl_data = []

with open(input_file, "r", encoding="utf-8") as file:
    for line in file:
        jsonl_data.append(json.loads(line))

updated_jsonl_data = []

for entry in tqdm(jsonl_data, desc="Processing rows"):
    content = entry[0]
    entities = entry[1]["entities"]

    for keyword in disaster_keywords:
        if isinstance(keyword, str):
            lowercase_keyword = keyword.lower()
        else:
            lowercase_keyword = str(keyword).lower()
        
        pattern = r'\b' + re.escape(lowercase_keyword) + r'\b'
        matches = re.finditer(pattern, content.lower())
        for match in matches:
            start_idx = match.start()
            end_idx = match.end()
            if [start_idx, end_idx, "DISASTER"] not in entities:
                entities.append([start_idx, end_idx, "DISASTER"])
    
    updated_jsonl_data.append([content, {"entities": entities}])

output_file = "../datasets/test/2xjp.jsonl"

with open(output_file, "w") as jsonl_file:
    for entry in updated_jsonl_data:
        json.dump(entry, jsonl_file)
        jsonl_file.write("\n")
# Out:
# Processing rows:   0%|          | 0/755 [00:00<?, ?it/s]
# Processing rows: 100%|██████████| 755/755 [00:00<00:00, 1851.73it/s]

# %%
def has_overlap(entities):
    for i, (start1, end1, _) in enumerate(entities):
        if start1 >= end1: 
            raise ValueError("Invalid entity: start must be less than end")
        for j, (start2, end2, _) in enumerate(entities):
            if start2 >= end2:
                raise ValueError("Invalid entity: start must be less than end")
            if i != j and (start1 < end2 and start2 < end1):  
                return True
    return False

def keep_largest_entity(entities):
    
    entities.sort(key=lambda x: (x[0], x[1] - x[0]), reverse=True)
    
    non_overlapping_entities = []
    
    for entity in entities:
        overlap_found = False
        for existing_entity in non_overlapping_entities:
            if (entity[0] < existing_entity[1] and entity[1] > existing_entity[0]):
                overlap_found = True
                break
        if not overlap_found:
            non_overlapping_entities.append(entity)
    
    return non_overlapping_entities

def filter_non_overlapping_lines(input_file, output_file):
    with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
        for line in infile:
            data = json.loads(line)
            content = data[0]
            entities = data[1].get("entities", [])
            
            adjusted_entities = keep_largest_entity(entities)
            
            if not has_overlap(adjusted_entities):  
                data[1]['entities'] = adjusted_entities 
                json.dump(data, outfile)
                outfile.write("\n")

input_file = "../datasets/test/2xjp.jsonl"
output_file = "../datasets/test/3xjp.jsonl"
filter_non_overlapping_lines(input_file, output_file)

# %%
def remove_empty_entities(input_file, output_file):
    with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
        for line in infile:
            tweet = json.loads(line)

            if tweet[1]["entities"]:
                json.dump(tweet, outfile, ensure_ascii=False)
                outfile.write("\n")

input_file = "../datasets/test/3xjp.jsonl"  
output_file = "../datasets/test/4xjp.jsonl"  

remove_empty_entities(input_file, output_file)

# %%
from langdetect import detect

def filter_english_lines(input_file, output_file):
    filtered_data = []
    
    with open(input_file, "r", encoding="utf-8") as infile:
        for line in infile:
            text, annotations = json.loads(line)
            try:
                if detect(text) == "en":
                    filtered_data.append((text, annotations))
            except Exception as e:
                print(f"Error detecting language for line: {line.strip()}\n{e}")

    with open(output_file, "w", encoding="utf-8") as outfile:
        for item in filtered_data:
            outfile.write(json.dumps(item) + "\n")
    
    print(f"Filtered data saved to {output_file}")

input_file = "../datasets/test/4xjp.jsonl"  
output_file = "../datasets/test/5xjp.jsonl"  
filter_english_lines(input_file, output_file)
# Out:
# Filtered data saved to ../datasets/test/5xjp.jsonl
